# %% [markdown]
# ## DEĞİŞKENLER

# %%
x = 5
y = 2.5
z = "Merhaba"
t = True

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
type(z)
# Out:
# str

# %%
type(t)
# Out:
# bool

# %% [markdown]
# ## String Methods

# %%
isim = "BEKDIKHAN"

# %%
Lower_Case_isim = isim.lower()

# %%
print(Lower_Case_isim)
# Out:
# bekdikhan

# %% [markdown]
# ## Slicing

# %%
Bihter_String = "tabi siz anneleri tarafından size emanet edilen çocuklara her bakımdan yetersiz gördüğünüz bir kadının annelik etmesine şiddetle karşısınız ama!"

# %%
Bihter_String [4:-1:5]
# Out:
# ' aeansetloaekne üz nnke eks '

# %% [markdown]
# ## Listeler

# %%
Bihter_List = ["tabi", "siz", "anneleri", "tarafından", "size", "emanet", "edilençocuklara", "her", "bakımdan", "yetersiz", "gördüğünüz", "bir", "kadının", "annelik", "etmesine", "şiddetle", "karşısınız", ]

# %%
Bihter_List.append("ama!")

# %%
print(Bihter_List)
# Out:
# ['tabi', 'siz', 'anneleri', 'tarafından', 'size', 'emanet', 'edilençocuklara', 'her', 'bakımdan', 'yetersiz', 'gördüğünüz', 'bir', 'kadının', 'annelik', 'etmesine', 'şiddetle', 'karşısınız', 'ama!']

# %%
Bihter_List.pop()
# Out:
# 'ama!'

# %%
Bihter_List.remove("tabi")

# %%
print(Bihter_List)
# Out:
# ['siz', 'anneleri', 'tarafından', 'size', 'emanet', 'edilençocuklara', 'her', 'bakımdan', 'yetersiz', 'gördüğünüz', 'bir', 'kadının', 'annelik', 'etmesine', 'şiddetle', 'karşısınız']

# %%
Nested_List = [10 , 20 , 30 , [40 , 50]]

# %%
Nested_List[3]
# Out:
# [40, 50]

# %%
Nested_List[3][0]
# Out:
# 40

# %%
Nested_List.reverse()

# %%
Nested_List
# Out:
# [[40, 50], 30, 20, 10]

# %% [markdown]
# ## Sözlükler

# %%
Class_Grades_Dict ={"Ali" : 100 , "Buse" : 92 , "Cengiz" : 83 }

# %%
Class_Grades_Dict.keys()
# Out:
# dict_keys(['Ali', 'Buse', 'Cengiz'])

# %%
Class_Grades_Dict ["Buse"]
# Out:
# 92

# %% [markdown]
# ## Setler

# %%
Yeni_Set = {1 , 1 , 2 , 3 , 4 , 5 , 3 , 6}

# %%
Yeni_Set
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
len(Yeni_Set)
# Out:
# 6

# %%
sum(Yeni_Set)
# Out:
# 21

# %% [markdown]
# ## Kıyaslamalar

# %%
x = 10
y = 5

# %%
x <= y
# Out:
# False

# %%
x > y and y > 2
# Out:
# True

# %%
not x < y
# Out:
# True

# %%
x != y
# Out:
# True

# %%
False or False
# Out:
# False
