# %%
theName = input("say my name\n")
if theName.replace(" ","").lower() == 'heisenberg' :
    print('you goddamn right')
# Out:
# say my name
#  sad

# %%
import random
i = 5
while(i > 0):
    print(f"heisenberg {i}")
    i= i-1
# Out:
# heisenberg 5
# heisenberg 4
# heisenberg 3
# heisenberg 2
# heisenberg 1

# %%
fruits= ["apple","banana","dragonfruit","onepiece"]

# %%
for fruit in fruits:
    print(fruit)
print("biti")
# Out:
# apple
# banana
# dragonfruit
# onepiece
# biti

# %%
import random
a = input("bir sayı giriniz")
i=1
patladimi = False
print("5 kere %50 şansı tuttturursan yaşarsın")
while i<6:
    if random.uniform(0,1) > 0.5:
        print(f"bomba {i}. seferde patladı")
        patladimi = True 
    else:
        print(f"{i}. seferde de kurtuldun helal")
    if patladimi:
        print("öldün")
        i= 7
    i= i+1
# Out:
# bir sayı giriniz 123
# 5 kere %50 şansı tuttturursan yaşarsın
# 1. seferde de kurtuldun helal
# 2. seferde de kurtuldun helal
# 3. seferde de kurtuldun helal
# bomba 4. seferde patladı
# öldün
