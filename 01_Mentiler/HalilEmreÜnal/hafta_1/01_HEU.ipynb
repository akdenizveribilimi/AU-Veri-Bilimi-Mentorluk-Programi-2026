# %%
print('o yeah')
# Out:
# o yeah

# %%
5*5
# Out:
# 25

# %%
5==5
# Out:
# True

# %%
x = 4
type(x)
# Out:
# int

# %%
a = x.to_bytes
print(a)
# Out:
# <built-in method to_bytes of int object at 0x00007FFE7073E4D8>

# %%
x=5

# %%
x % 2
# Out:
# 1

# %%
x^5
# Out:
# 0

# %%
x ** 5
# Out:
# 3125

# %%
y = 2

# %%
a = x/y

# %%
print(a)
# Out:
# 2.5

# %%
type(a)
# Out:
# float

# %%
type(x)
# Out:
# int

# %%
theName = input("say my name\n")
if theName.replace(" ","").lower() == 'heisenberg' :
    print('you goddamn right')
# Out:
# say my name
#  HeiS EnBerG
# you goddamn right

# %%
k = "morpheus"
print(len(k))
# Out:
# 8

# %%
shit = "as"

# %%
type(shit)
# Out:
# str

# %%
print(f"{5+3} asd")
# Out:
# 8 asd

# %% [raw]
# print("asd" + 3)

# %%
x=5

# %%
print(f"{}")

# %%
for i in range(12):
    print(f"Bombanin Patlamasına {12-i} saniye")
# Out:
# Bombanin Patlamasına 12 saniye
# Bombanin Patlamasına 11 saniye
# Bombanin Patlamasına 10 saniye
# Bombanin Patlamasına 9 saniye
# Bombanin Patlamasına 8 saniye
# Bombanin Patlamasına 7 saniye
# Bombanin Patlamasına 6 saniye
# Bombanin Patlamasına 5 saniye
# Bombanin Patlamasına 4 saniye
# Bombanin Patlamasına 3 saniye
# Bombanin Patlamasına 2 saniye
# Bombanin Patlamasına 1 saniye
