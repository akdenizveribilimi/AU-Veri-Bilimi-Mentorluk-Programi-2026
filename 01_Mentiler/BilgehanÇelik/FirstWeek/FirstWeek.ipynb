# %% [markdown]
# VARIABLES

# %%
variableList = [2026, 2026.2026, "2026", True, ["a", "b", "c"], {1,2,3}]

# %% [raw]
# my_dict = {}
# count = 0
# for i in variableList[4]:
#     dict.update({i : count})
#     count += 1
# variableList.append(dict)

# %%
for i in variableList:
    print(type(i).__name__)
# Out:
# int
# float
# str
# bool
# list
# set

# %% [markdown]
# SLICING and STRING METHODS

# %%
myStr = "Sevmeyeni Bırakın"

# %%
print(myStr[5:9].capitalize() + " " + myStr[12:16].capitalize())
# Out:
# Yeni Rakı

# %% [markdown]
# LISTS etc.

# %%
myList = ["P", {1 : 1, "a" : "AA", "y" : ["j", 97, "t"]}, ["lafs", "h"], "o", "n"]

# %%
print(myList[0] + list(myList[1].keys())[2] + myList[1]["y"][2] + myList[2][1] + myList[3] + myList[4])
# Out:
# Python

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
diller = ["Python", "C++", "Java"]
for i, dil in enumerate(diller):
    print(f"{i}. indeksteki dil: {dil}")
# Out:
# 0. indeksteki dil: Python
# 1. indeksteki dil: C++
# 2. indeksteki dil: Java
