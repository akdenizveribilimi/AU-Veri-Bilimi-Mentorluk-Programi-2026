# %% [markdown]
# # VARIABLES

# %%
x=10

# %%
type(x)
# Out:
# int

# %%
y=3.5

# %%
type(y)
# Out:
# float

# %%
z="Ayşegül Kızılırmak"

# %%
type(z)
# Out:
# str

# %%
print(x*y+len(z))
# Out:
# 53.0

# %% [markdown]
# # STRING METHODS

# %%
isim= "ayşegül"

# %%
soyisim= "kızılırmak"

# %%
isimsoyisim = isim.capitalize() + " " + soyisim.capitalize()

# %%
print(isimsoyisim)
# Out:
# Ayşegül Kızılırmak

# %% [markdown]
# # SLICING

# %%
karisikString= "Ayşegül Kızılırmak"

# %%
print(karisikString[3:])
# Out:
# egül Kızılırmak

# %%
print(karisikString[:5])
# Out:
# Ayşeg

# %%
print(karisikString[2:8])
# Out:
# şegül

# %%
print(karisikString[2:12:2])
# Out:
# şglKz

# %%
print(karisikString[::-3])
# Out:
# krıKüş

# %% [markdown]
# # LISTS

# %%
liste1 = [10 , 20 , 30 , 40]

# %%
print(liste1)
# Out:
# [10, 20, 30, 40]

# %%
liste1.append(50)

# %%
print(liste1)
# Out:
# [10, 20, 30, 40, 50]

# %%
print(liste1[2])
# Out:
# 30

# %%
colors=["red","yellow","blue","black"]

# %%
print(colors)
# Out:
# ['red', 'yellow', 'blue', 'black']

# %%
print(colors[3])
# Out:
# black

# %%
colors.append("pink")

# %%
print(colors)
# Out:
# ['red', 'yellow', 'blue', 'black', 'pink']

# %%
colors.remove("blue")

# %%
print(colors)
# Out:
# ['red', 'yellow', 'black', 'pink']

# %%
colors.reverse()

# %%
colors
# Out:
# ['pink', 'black', 'yellow', 'red']

# %%
nestedList = [10, 2.5, "Ayşegül", 25, [55, "veri"]]

# %%
str3 = nestedList[4][1]

# %%
print(str3)
# Out:
# veri

# %% [markdown]
# # DICTIONARY

# %%
colorPrices={"pink" : 500 , "yellow" : 440 , "red" : 160}

# %%
print(colorPrices.keys())
# Out:
# dict_keys(['pink', 'yellow', 'red'])

# %%
print(colorPrices.values())
# Out:
# dict_values([500, 440, 160])

# %%
print(colorPrices["yellow"])
# Out:
# 440

# %% [markdown]
# # SET

# %%
newSet = {3, 7, 3, 12, 8, 45, 12, 99, 7, 21, 3}

# %%
type(newSet)
# Out:
# set

# %%
newSet
# Out:
# {3, 7, 8, 12, 21, 45, 99}

# %%
newSet.add(4567)

# %%
newSet
# Out:
# {3, 7, 8, 12, 21, 45, 99, 4567}

# %% [markdown]
# # BOOL AND COMPARISONS

# %%
x=7

# %%
y=3.4

# %%
x <= y
# Out:
# False

# %%
x > y
# Out:
# True

# %%
x < -100 and y > 35
# Out:
# False

# %%
x < 87 or y >= 1
# Out:
# True

# %%
not y == 3.4
# Out:
# False
